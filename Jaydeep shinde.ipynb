# %%
MCQ:
    1) only interpreted
    2) to identified the variable
    3)you dont have covid, test says you have covid
    4)84
    5)*

# %%
#1
a= input("enter you name")
a[0:len(a):2]
# Out:
# enter you namejaydeepshinde
# 'jyephne'

# %%
#2
n= [12,75,150,180,145,525,50]
for i in (n):
    if i>150:
        continue
    elif i>500:
        break
    elif i%5==0:
        print(i,"is divisible by 5")
else:
        pass
# Out:
# 75 is divisible by 5
# 150 is divisible by 5
# 145 is divisible by 5
# 50 is divisible by 5

# %%
#3
n= [1,2,3,4,5,6,7]
for i in n:
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49

# %%
#4
days= ['sun','mon','tue','wed','fri','sat']
temp = [30.5,32.6,31.8,33.4,29.8,30.2,29.9]
dict_m ={i:j for i,j in zip(days,temp)} 
dict_m
# Out:
# {'sun': 30.5, 'mon': 32.6, 'tue': 31.8, 'wed': 33.4, 'fri': 29.8, 'sat': 30.2}

# %%
#5
there is 52 cards in a deck and in one dack there is 4 kings 
so p(king)= 4/52

# %%
#6
class car:
    def __init__(self,price,brand,milage):
        print(" in constructor")
        self.__price = price
        self.brand = brand
        self.milage = milage
        
        
    def buy(self):
        
        print("Buy a car")
        
class bike(car):
    
    def buy(self):
        print("Buying a BMW bike")

# %%
b1 = bike(25000,'BMW',45)
# Out:
#  in constructor

# %%
b1.buy()
# Out:
# Buying a BMW bike

# %% [markdown]
#  it has two class and 1 constructor , same method in 2nd class This is called method overriding

# %%
#7
Number = int(input("enter the number"))
if Number%5==0 and Number%7==0:
    print(Number,"is multiple of 5 and 7")
# Out:
# enter the number35
# 35 is multiple of 5 and 7

# %%
#8
types of distribution 
1) Normal distribution
2) uniform distribution
3) binomial distribution
4)burnoli distribution
5)standared distribution
6)pmf
7)pdf
8)cdf

# %%
#9
Central Limit Theorem:
the central limit theorem states that the distribution of a sample variable approximates a normal distribution
the sample size should not exceed 10% of the population.
in CLT data or sample is select from random there no any rule to get the sample.
it tha sample not related to each other if we choose one sample it will does not affect the other samples. samples take without replacement.

# %%
#10
def cal(a,b):
    a+b,a-b,a*b,a/b
    return(a+b,a-b,a*b,a/b)

# %%
cal(2,5)
# Out:
# (7, -3, 10, 0.4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("supermarket.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
df.drop(['Invoice ID'],axis = 1, inplace=True)

# %%
df.drop(['Date'],axis = 1, inplace=True)

# %%
df.drop(['Time'],axis = 1, inplace=True)

# %%
df.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total      Payment    cogs  gross margin percentage  \
# 0         7  26.1415  548.9715      Ewallet  522.83                 4.761905
# 1         5   3.8200   80.2200         Cash   76.40                 4.761905
# 2         7  16.2155  340.5255  Credit card  324.31                 4.761905
# 3         8  23.2880  489.0480      Ewallet  465.76                 4.761905
# 4         7  30.2085  634.3785      Ewallet  604.17                 4.761905
#
#    gross income  Rating
# ...

# %%
df.isnull().sum()
# Out:
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df1 = df.groupby('Payment')['Gender']
print(df1)

# %%
sns.boxplot(x= df['Total'])
# Out:
# <Axes: xlabel='Total'>

# %%
column total has outlier

# %%
sns.boxplot(x= df['cogs'])
# Out:
# <Axes: xlabel='cogs'>

# %%
column cogs has outlier

# %%
corr = df.corr()
corr
# Out:
# C:\Users\jayde\AppData\Local\Temp\ipykernel_119888\2438084875.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# ...

# %%
sns.heatmap(corr,cmap=['green','yellow','blue','red'],vmin = -.5,vmax = 0.6,
            annot = True)
# Out:
# <Axes: >

# %%
sns.countplot(x='Gender',data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df[]
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total      Payment    cogs  \
# 0         74.69         7  26.1415   548.9715      Ewallet  522.83
# ...

# %%
sns.countplot(x='Payment',hue='Gender',data = df)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %% [raw]
# Faction accessories has higest selling category
